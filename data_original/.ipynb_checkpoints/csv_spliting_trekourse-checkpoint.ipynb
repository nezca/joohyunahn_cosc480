# %%
# pandas import
import pandas as pd

csv_data_2 = pd.read_csv('Trekourse_dataset.csv', encoding='UTF8')
print("In the case of the prototype, would you input number '3' for the difficulty?'")
difficulty = input("How much hard do you want to? ")

print("In the case of the prototype, would you input number '8000' for the distance?'")
distance = input("How long distance do you want to trek? ")

print("In the case of the prototype, would you input number '5' for the nights?'")
nights = input("How many nights do you want to stay on the trail course? ")

results = csv_data_2[(csv_data_2.difficulty_level_1 >= float(difficulty)) &
           (csv_data_2.duration_nights <= float(nights)) &
           (csv_data_2.length <= float(distance))]

filtered_results = results[['UID', 'name', 'distance', 'course_style', 'difficulty']]

print(filtered_results)
# Out:
# In the case of the prototype, would you input number '3' for the difficulty?'
# How much hard do you want to?  3
# In the case of the prototype, would you input number '8000' for the distance?'
# How long distance do you want to trek?  8000
# In the case of the prototype, would you input number '5' for the nights?'
# How many nights do you want to stay on the trail course?  5
#      UID                            name        distance course_style  \
# 48   455        Kaimai Summit Loop Track    379.81 meter      one_way
# 50   531            Mt Burns Tarns Track    385.92 meter       return
# 52   111    Tomahawk Lagoon/41-Peg Track    402.25 meter      one_way
# 63   816              Te Hapua Bay Track    462.93 meter      one_way
# 66   396                Twin Kauri Track    475.37 meter      one_way
# ..   ...                             ...             ...          ...
# 621  540                   Parapara Peak  7.94 kilometer      one_way
# 622   78               Mt Fishtail Route  7.94 kilometer      one_way
# 623   12             Iron Gate Hut Track  7.95 kilometer      one_way
# 624  802              Lake Daniell Track  7.95 kilometer      one_way
# 626  932  Quartz Creek/Mount Royal Route  7.98 kilometer       return
#
#        difficulty
# 48       Advanced
# 50       Advanced
# 52       Advanced
# 63       Advanced
# 66       Advanced
# ..            ...
# 621        Expert
# 622        Expert
# 623      Advanced
# 624  Intermediate
# 626        Expert
#
# [204 rows x 5 columns]

# %% [markdown]
# FLASK 이용 웹 구현
# https://blog.naver.com/PostView.nhn?blogId=poiulkj321&logNo=221367814773&parentCategoryNo=&categoryNo=14&viewDate=&isShowPopularPosts=true&from=search

# %%
# pandas import
import pandas as pd

csv_data_2 = pd.read_csv('Trekourse_dataset.csv', encoding='UTF8', index_col="name_first")
csv_data_2
# Out:
#                                  UID              X          Y  \
# name_first
# Kepler Track\n                     1  167.6827234\n -45.469489
# Five Mile Bay and Awaroa Tracks    2    176.0745315 -38.761418
# Oromahoe Traverse                  3     174.074665 -35.306620
# Papaitonga Scenic Reserve walks    4    175.2325144 -40.646553
# Melina Ridge Track                 5    169.5808408 -44.459488
# ...                              ...            ...        ...
# Mt Patriarch Route               957    173.2522233 -41.597229
# Maunganui Bluff Track            958    173.5559909 -35.746185
# Big Tōtara Walk                  959    167.6354101 -45.866411
# Zekes Hut Track                  960    175.7349757 -39.541521
# Ferndale tracks                  961    173.9725344 -41.189484
#
#                                                                     name_second  \
# name_first
# Kepler Track\n                    Rainbow Reach to Shallow Bay or Moturau Hut\n
# Five Mile Bay and Awaroa Tracks                                             NaN
# Oromahoe Traverse                                                           NaN
# Papaitonga Scenic Reserve walks                                             NaN
# Melina Ridge Track                                                          NaN
# ...                                                                         ...
# Mt Patriarch Route                                                          NaN
# Maunganui Bluff Track                                                       NaN
# Big Tōtara Walk                                                             NaN
# Zekes Hut Track                                                             NaN
# Ferndale tracks                                                             NaN
#
#                                                                       introduction  \
# name_first
# Kepler Track\n                   To sample the Kepler Track (a Great Walk) or f...
# Five Mile Bay and Awaroa Tracks  These family friendly tracks stretch along the...
# Oromahoe Traverse                Enjoy lovely forest and sea views on the Oroma...
# Papaitonga Scenic Reserve walks  Take a short, easy walk around a dune lake wit...
# Melina Ridge Track               This is a classic mountain bike ride located i...
# ...                                                                            ...
# Mt Patriarch Route                 Walk or mountain bike up Mt Patriarch (1656 m).
# Maunganui Bluff Track            Climb up and over an ancient volcanic crater f...
# Big Tōtara Walk                  This short walking track winds through forest ...
# Zekes Hut Track                  An ideal day hike or easy overnight tramp to a...
# Ferndale tracks                  From the Ferndale campsite there is a 15 minut...
#
#                                      difficulty  \
# name_first
# Kepler Track\n                   Intermediate\n
# Five Mile Bay and Awaroa Tracks         Easiest
# Oromahoe Traverse                  Intermediate
# Papaitonga Scenic Reserve walks         Easiest
# Melina Ridge Track                     Advanced
# ...                                         ...
# Mt Patriarch Route                       Expert
# Maunganui Bluff Track             Easy,Advanced
# Big Tōtara Walk                            Easy
# Zekes Hut Track                        Advanced
# Ferndale tracks                            Easy
#
#                                                                     completionTime  \
# name_first
# Kepler Track\n                                            3 - 3 hr 30 min return\n
# Five Mile Bay and Awaroa Tracks                                       30 min - 1hr
# Oromahoe Traverse                                              2 hr 30 min one way
# Papaitonga Scenic Reserve walks                                    10 min | 20 min
# Melina Ridge Track                                                       8 - 10 hr
# ...                                                                            ...
# Mt Patriarch Route                                                  5–6 hr one way
# Maunganui Bluff Track            1 hr 30 min to Maunganui Bluff | 5 hr to Waika...
# Big Tōtara Walk                                                      30 min return
# Zekes Hut Track                                  2 hr 30 min - 3 hr 30 min one way
# Ferndale tracks                                                      15 min - 1 hr
#
#                                      length difficulty_level_1  \
# name_first
# Kepler Track\n                   15603.61\n                3\n
# Five Mile Bay and Awaroa Tracks     5128.95                  1
# Oromahoe Traverse                   5209.61                  3
# Papaitonga Scenic Reserve walks     1426.19                  1
# Melina Ridge Track                  4761.84                  4
# ...                                     ...                ...
# Mt Patriarch Route                  7664.47                  5
# Maunganui Bluff Track                8080.6                  2
# Big Tōtara Walk                      622.14                  2
# Zekes Hut Track                    10403.13                  4
# Ferndale tracks                      405.58                  2
#
#                                 difficulty_level_1.1 course_style  \
# name_first
# Kepler Track\n                                   1\n     return\n
# Five Mile Bay and Awaroa Tracks                    1      one_way
# Oromahoe Traverse                                  1      one_way
# Papaitonga Scenic Reserve walks                    1      one_way
# Melina Ridge Track                                 1      one_way
# ...                                              ...          ...
# Mt Patriarch Route                                 1      one_way
# Maunganui Bluff Track                              3      one_way
# Big Tōtara Walk                                    1       return
# Zekes Hut Track                                    1      one_way
# Ferndale tracks                                    1      one_way
#
#                                 duration_nights duration_up_to_time  \
# name_first
# Kepler Track\n                              0\n               3.5\n
# Five Mile Bay and Awaroa Tracks               0                   1
# Oromahoe Traverse                             0                 2.5
# Papaitonga Scenic Reserve walks               0                0.33
# Melina Ridge Track                            0                  10
# ...                                         ...                 ...
# Mt Patriarch Route                            0                   6
# Maunganui Bluff Track                         0                 1.5
# Big Tōtara Walk                               0                 0.5
# Zekes Hut Track                               0                 3.5
# Ferndale tracks                               0                   1
#
#                                           distance
# name_first
# Kepler Track\n                   15.61 kilometer\n
# Five Mile Bay and Awaroa Tracks     5.13 kilometer
# Oromahoe Traverse                   5.21 kilometer
# Papaitonga Scenic Reserve walks     1.43 kilometer
# Melina Ridge Track                  4.77 kilometer
# ...                                            ...
# Mt Patriarch Route                  7.67 kilometer
# Maunganui Bluff Track               8.09 kilometer
# Big Tōtara Walk                       622.15 meter
# Zekes Hut Track                    10.41 kilometer
# Ferndale tracks                       405.59 meter
#
# [961 rows x 14 columns]

# %%
csv_data_2["difficulty"]
# Out:
# name
# Kauri Stump Walk                                        Easy
# Waiau Falls and Kauri Grove Lookout Walk             Easiest
# Pakotai Track                                           Easy
# Square Kauri Tree                                    Easiest
# Milford Sound Lookout Track                             Easy
#                                                   ...
# Southern Circuit Stewart Island/Rakiura             Advanced
# Around the Mountain Circuit                  Advanced,Expert
# Pyke - Big Bay Route                                  Expert
# North West Circuit Stewart Island/Rakiura           Advanced
# Leslie-Karamea Track                                Advanced
# Name: difficulty, Length: 961, dtype: object

# %%
csv_data_2.iloc[1]
# Out:
# UID                                                                   395
# X                                                                 175.547
# Y                                                                -36.8321
# introduction            Visit a popular swimming hole at Waiau Falls a...
# difficulty                                                        Easiest
# completionTime                                              30 min return
# length                                                              70.69
# difficulty_level_1                                                      1
# difficulty_level_1.1                                                    1
# course_style                                                       return
# duration_nights                                                         0
# duration_up_to_time                                                   0.5
# distance                                                      70.69 meter
# Name: Waiau Falls and Kauri Grove Lookout Walk, dtype: object

# %%
# warning 없이 csv 데이터 한줄씩 읽어 내려가면서 csv로 다시 write하기

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd

a = []
if " " in csv_data_2.iloc[0][3]:
    a.append(csv_data_2.iloc[0][3].replace(" ", "_"))
a
# csv_data_2.iloc[a].to_csv("tes"+str(a)+".csv", index=False)
# Out:
# ['Kepler_Track']

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd

csv_data_2 = pd.read_csv('Trekourse_dataset_operate.csv', encoding='UTF8')

for i in range(len(csv_data_2)):
    if " " in csv_data_2.iloc[i][2]:
        csv_data_2.iloc[i].to_csv(str(csv_data_2.iloc[i][2].replace(" ", "_"))+"_"+str(i)+".csv", index = False)
